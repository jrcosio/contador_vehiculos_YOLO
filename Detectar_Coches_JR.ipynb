# %% [markdown]
# ## Contador de Objetos
# ##### por JR Blanco
#
# - Asignatura: Modelos de Inteligencia Artificial
#
# - ## [Enlace video](https://educantabria-my.sharepoint.com/:v:/g/personal/jblancog03_educantabria_es/EayeL3u8qSBGh1JOIt-ibz8BE6dEmHhrmCICxD3K0TTKZA?nav=eyJyZWZlcnJhbEluZm8iOnsicmVmZXJyYWxBcHAiOiJPbmVEcml2ZUZvckJ1c2luZXNzIiwicmVmZXJyYWxBcHBQbGF0Zm9ybSI6IldlYiIsInJlZmVycmFsTW9kZSI6InZpZXciLCJyZWZlcnJhbFZpZXciOiJNeUZpbGVzTGlua0NvcHkifX0&email=adiezc09%40educantabria.es&e=4JUCGT)

# %%
#Cargas las librerias necesarias
from ultralytics import YOLO
import cv2
import datetime

# %% [markdown]
# Cargamos el modelo Yolo Nano

# %%
model = YOLO('yolov8m.pt')
model.info()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8m.pt to 'yolov8m.pt'...
# 100%|██████████| 49.7M/49.7M [00:02<00:00, 20.6MB/s]
# YOLOv8m summary: 295 layers, 25902640 parameters, 0 gradients, 79.3 GFLOPs
# (295, 25902640, 0, 79.3204224)

# %% [markdown]
# ### Clase Objeto_Contar
#
# Decidí desarrollar mi propia clase para contar vehículos al cruzar una línea específica, por las deficiencias que encontré en las bibliotecas proporcionadas por ultralytics.solutions. Estas bibliotecas no lograban identificar de manera precisa todos los vehículos que pasaban, resultando en una cantidad significativa de falsos negativos. Esto derivó en una tasa de éxito apenas superior al 40%, un rendimiento muy por debajo de lo esperado.
#
# Tras un análisis detallado del objeto devuelto por el método .track, descubrí que 'boxes' es una lista que contiene los objetos detectados. Este hallazgo me impulsó a desarrollar mi propio detector, logrando una asombrosa tasa de acierto cercana al 99% con el material de video que utilicé para las pruebas. Este nuevo enfoque no solo superó ampliamente las limitaciones previas, sino que también estableció un precedente en la eficacia de la detección y conteo de vehículos en mi proyecto.

# %%
class Objeto_Contar:
    """
    Clase para contar objetos en una línea específica de un frame de video.
    """
    
    def __init__(self, linea, show_linea=True, color_linea=(0, 255, 0), color_texto=(0, 0, 0)):
        """
        Inicializa la clase Objeto_Contar.

        Parámetros:
        - linea: tupla, coordenadas de inicio y fin de la línea de conteo.
        - show_linea: bool, indica si se debe mostrar la línea de conteo en el frame.
        - color_linea: tupla, color de la línea de conteo en formato BGR.
        - color_texto: tupla, color del texto de conteo en formato BGR.
        """
        self.cuenta = 0
        self.inicio_linea = linea[0]
        self.fin_linea = linea[1]
        self.show_linea = show_linea
        self.color_linea = color_linea
        self.color_texto = color_texto
        self.__dicionario = {} #Para no contar el mismo objeto(id) dos veces o más
        
    def contar(self, frame, tracker):
        """
        Cuenta los objetos que cruzan la línea de conteo en el frame.

        Parámetros:
        - frame: numpy.ndarray, frame de video.
        - tracker: ultralytics.solutions.tracker.Tracker, objeto de seguimiento de objetos, se obtiene en el método detectar de la clase YOLO.

        """
        for caja in tracker[0].boxes:
            id = int(caja.id)
            x, y = caja.xywh[0][0], caja.xywh[0][1]
            
            if x > self.inicio_linea[0] and x < self.fin_linea[0] and y > self.inicio_linea[1]:
                if id not in self.__dicionario:
                    self.__dicionario[id] = True
                    self.cuenta += 1           
        
        if self.show_linea:
            cv2.line(frame, self.inicio_linea, self.fin_linea, self.color_linea, 1)
            cv2.rectangle(frame, (self.inicio_linea[0], self.inicio_linea[1]-13), (self.inicio_linea[0]+30, self.inicio_linea[1]), self.color_linea, -1)
            #Para mostrar el texto de la cuenta en el centro del rectangulo
            text = f"{self.cuenta}"
            text_size, _ = cv2.getTextSize(text, cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1)
            text_x = self.inicio_linea[0] + (30 - text_size[0]) // 2
            text_y = self.inicio_linea[1] - 2
            cv2.putText(frame, text, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 0.4, self.color_texto, 1)

# %% [markdown]
# Cargar el Video

# %%
video = './trafficCam.mp4'

# %% [markdown]
# Definine las lineas para usar de contadores

# %%
#Lineas para el conteo de objetos
lineaA = ((40, 480), (500, 480))
lineaB = ((525, 480), (745, 480))
lineaC = ((850, 480), (1190, 480))

# %% [markdown]
# ### Main - Principal

# %%
captura = cv2.VideoCapture(video)

#Objetos para contar, uno por cada línea
obj_contador_A = Objeto_Contar(linea=lineaA, color_linea=(0, 255, 0))
obj_contador_B = Objeto_Contar(linea=lineaB, color_linea=(255, 255, 0))
obj_contador_C = Objeto_Contar(linea=lineaC, color_linea=(0, 255, 255))

while True:
    start = datetime.datetime.now() #Contador de tiempo para los FPS - Tiempos Inicial
    
    ret, frame = captura.read() #Lee cada frame del video
    if not ret:
        break
    
    resultado = model.track(frame, persist=True) #Detecta los objetos y hace el track
    
    #Metodos de la clase Objeto_Contar que cuenta si los objetos pasan la linea
    obj_contador_A.contar(frame, resultado) 
    obj_contador_B.contar(frame, resultado) 
    obj_contador_C.contar(frame, resultado) 
    
    end = datetime.datetime.now() #Contador de tiempo para los FPS - Tiempo Final
    
    fps = f"FPS: {1 / (end - start).total_seconds():.2f}" #Calculo los FPS
    cv2.putText(frame, fps, (10, 25), 1, 1, (0, 0, 255), 2) #Muestro en pantalla los FPS
    
    cv2.imshow('Video', resultado[0].plot(line_width=1)) #Muestro la visualización del resultado del tracks -> Dibuja la dDtección de los vehiculos
    #cv2.imshow('Video', frame)
    if cv2.waitKey(1) == 27:   #Metodo para salir del bucle al pulsa ESC
        break

captura.release()
cv2.destroyAllWindows()

#Muestra el resultado al finalizar el video
print("\nConteo de vehiculos por linea")
print(f"Total de vehiculos que pasaron por la linea A: {obj_contador_A.cuenta}")
print(f"Total de vehiculos que pasaron por la linea B: {obj_contador_B.cuenta}")
print(f"Total de vehiculos que pasaron por la linea C: {obj_contador_C.cuenta}")
# Out:
# 0: 384x640 7 cars, 73.2ms
# Speed: 4.0ms preprocess, 73.2ms inference, 361.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 32.5ms
# Speed: 4.2ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 33.2ms
# Speed: 2.5ms preprocess, 33.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 34.0ms
# Speed: 1.7ms preprocess, 34.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 33.8ms
# Speed: 1.7ms preprocess, 33.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 29.4ms
# Speed: 2.3ms preprocess, 29.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 29.1ms
# Speed: 2.4ms preprocess, 29.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 29.5ms
# Speed: 4.1ms preprocess, 29.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 29.6ms
# Speed: 2.4ms preprocess, 29.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 28.6ms
# Speed: 3.9ms preprocess, 28.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 28.8ms
# Speed: 4.0ms preprocess, 28.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 27.3ms
# Speed: 3.3ms preprocess, 27.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 25.9ms
# Speed: 1.6ms preprocess, 25.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.6ms
# Speed: 2.6ms preprocess, 26.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 24.8ms
# Speed: 2.3ms preprocess, 24.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 25.0ms
# Speed: 3.0ms preprocess, 25.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 26.0ms
# Speed: 2.5ms preprocess, 26.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.4ms
# Speed: 2.4ms preprocess, 26.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.3ms
# Speed: 1.9ms preprocess, 26.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 25.3ms
# Speed: 2.2ms preprocess, 25.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 27.1ms
# Speed: 1.8ms preprocess, 27.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 27.2ms
# Speed: 2.6ms preprocess, 27.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 27.1ms
# Speed: 1.8ms preprocess, 27.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.4ms
# Speed: 2.0ms preprocess, 26.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.5ms
# Speed: 2.1ms preprocess, 26.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.4ms
# Speed: 3.4ms preprocess, 26.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.6ms
# Speed: 2.2ms preprocess, 26.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.4ms
# Speed: 2.7ms preprocess, 26.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.4ms
# Speed: 2.1ms preprocess, 26.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.8ms
# Speed: 2.0ms preprocess, 26.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.8ms
# Speed: 1.7ms preprocess, 26.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 24.9ms
# Speed: 2.2ms preprocess, 24.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.6ms
# Speed: 3.4ms preprocess, 26.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.6ms
# Speed: 2.2ms preprocess, 26.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.4ms
# Speed: 1.7ms preprocess, 26.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.4ms
# Speed: 1.7ms preprocess, 26.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.0ms
# Speed: 1.7ms preprocess, 26.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.3ms
# Speed: 1.6ms preprocess, 26.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.7ms
# Speed: 1.9ms preprocess, 26.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 27.0ms
# Speed: 2.4ms preprocess, 27.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.2ms
# Speed: 2.0ms preprocess, 26.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.2ms
# Speed: 2.5ms preprocess, 26.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.2ms
# Speed: 1.7ms preprocess, 26.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 24.8ms
# Speed: 1.7ms preprocess, 24.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 27.1ms
# Speed: 2.3ms preprocess, 27.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.4ms
# Speed: 1.9ms preprocess, 26.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 26.6ms
# Speed: 4.0ms preprocess, 26.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.5ms
# Speed: 2.0ms preprocess, 26.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.2ms
# Speed: 2.0ms preprocess, 26.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 26.4ms
# Speed: 1.7ms preprocess, 26.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.7ms
# Speed: 1.9ms preprocess, 26.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 27.5ms
# Speed: 2.3ms preprocess, 27.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 27.0ms
# Speed: 1.7ms preprocess, 27.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 27.8ms
# Speed: 6.4ms preprocess, 27.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 27.3ms
# Speed: 1.5ms preprocess, 27.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 27.2ms
# Speed: 2.9ms preprocess, 27.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.8ms
# Speed: 1.7ms preprocess, 26.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 25.7ms
# Speed: 1.8ms preprocess, 25.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 27.2ms
# Speed: 3.3ms preprocess, 27.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 25.4ms
# Speed: 2.1ms preprocess, 25.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 25.4ms
# Speed: 1.9ms preprocess, 25.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.3ms
# Speed: 2.0ms preprocess, 26.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.4ms
# Speed: 1.7ms preprocess, 26.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.4ms
# Speed: 1.9ms preprocess, 26.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 24.6ms
# Speed: 2.2ms preprocess, 24.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.1ms
# Speed: 3.7ms preprocess, 26.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.1ms
# Speed: 2.2ms preprocess, 26.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.2ms
# Speed: 2.9ms preprocess, 26.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.7ms
# Speed: 2.7ms preprocess, 26.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.5ms
# Speed: 2.7ms preprocess, 26.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.7ms
# Speed: 2.3ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.9ms
# Speed: 2.0ms preprocess, 26.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 27.1ms
# Speed: 2.8ms preprocess, 27.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.7ms
# Speed: 1.7ms preprocess, 26.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.9ms
# Speed: 2.7ms preprocess, 26.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.5ms
# Speed: 2.5ms preprocess, 26.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 26.8ms
# Speed: 1.6ms preprocess, 26.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 26.7ms
# Speed: 1.6ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 27.2ms
# Speed: 1.9ms preprocess, 27.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 26.8ms
# Speed: 1.7ms preprocess, 26.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.8ms
# Speed: 5.0ms preprocess, 26.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.5ms
# Speed: 2.9ms preprocess, 26.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.3ms
# Speed: 1.6ms preprocess, 26.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.5ms
# Speed: 2.7ms preprocess, 26.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.3ms
# Speed: 5.9ms preprocess, 26.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.2ms
# Speed: 2.4ms preprocess, 26.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.6ms
# Speed: 2.6ms preprocess, 26.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 27.3ms
# Speed: 1.6ms preprocess, 27.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.7ms
# Speed: 3.5ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.8ms
# Speed: 2.0ms preprocess, 26.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.7ms
# Speed: 1.6ms preprocess, 26.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 27.0ms
# Speed: 2.4ms preprocess, 27.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.6ms
# Speed: 1.6ms preprocess, 26.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.9ms
# Speed: 3.9ms preprocess, 26.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 27.1ms
# Speed: 1.7ms preprocess, 27.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.8ms
# Speed: 2.1ms preprocess, 26.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 27.6ms
# Speed: 2.5ms preprocess, 27.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 27.3ms
# Speed: 1.8ms preprocess, 27.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 27.1ms
# Speed: 1.8ms preprocess, 27.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.9ms
# Speed: 3.6ms preprocess, 26.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 27.2ms
# Speed: 3.0ms preprocess, 27.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 27.5ms
# Speed: 2.1ms preprocess, 27.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 27.0ms
# Speed: 2.0ms preprocess, 27.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 27.8ms
# Speed: 3.2ms preprocess, 27.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 27.2ms
# Speed: 3.3ms preprocess, 27.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 27.2ms
# Speed: 4.4ms preprocess, 27.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 27.3ms
# Speed: 2.1ms preprocess, 27.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.4ms
# Speed: 3.1ms preprocess, 26.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 25.6ms
# Speed: 2.0ms preprocess, 25.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 25.7ms
# Speed: 2.4ms preprocess, 25.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 24.5ms
# Speed: 1.8ms preprocess, 24.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.9ms
# Speed: 2.0ms preprocess, 26.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.8ms
# Speed: 1.9ms preprocess, 26.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 25.2ms
# Speed: 2.8ms preprocess, 25.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.3ms
# Speed: 1.8ms preprocess, 26.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.4ms
# Speed: 3.0ms preprocess, 26.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.2ms
# Speed: 1.8ms preprocess, 26.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.2ms
# Speed: 1.9ms preprocess, 26.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.8ms
# Speed: 2.5ms preprocess, 26.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.5ms
# Speed: 1.9ms preprocess, 26.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.8ms
# Speed: 2.2ms preprocess, 26.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.6ms
# Speed: 2.0ms preprocess, 26.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.4ms
# Speed: 2.2ms preprocess, 26.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.7ms
# Speed: 1.6ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.7ms
# Speed: 2.5ms preprocess, 26.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.3ms
# Speed: 2.2ms preprocess, 26.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.6ms
# Speed: 1.9ms preprocess, 26.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.3ms
# Speed: 2.1ms preprocess, 26.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.3ms
# Speed: 2.2ms preprocess, 26.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.2ms
# Speed: 2.2ms preprocess, 26.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.9ms
# Speed: 2.1ms preprocess, 26.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.6ms
# Speed: 2.0ms preprocess, 26.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 25.7ms
# Speed: 1.9ms preprocess, 25.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.6ms
# Speed: 1.8ms preprocess, 26.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.0ms
# Speed: 2.4ms preprocess, 26.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.2ms
# Speed: 2.6ms preprocess, 26.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.1ms
# Speed: 1.5ms preprocess, 26.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.8ms
# Speed: 2.0ms preprocess, 26.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.9ms
# Speed: 1.9ms preprocess, 26.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 27.2ms
# Speed: 1.7ms preprocess, 27.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 27.2ms
# Speed: 1.7ms preprocess, 27.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 27.3ms
# Speed: 2.6ms preprocess, 27.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.5ms
# Speed: 2.0ms preprocess, 26.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.2ms
# Speed: 3.1ms preprocess, 26.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.7ms
# Speed: 3.2ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.7ms
# Speed: 3.0ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.7ms
# Speed: 3.0ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 27.0ms
# Speed: 2.8ms preprocess, 27.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.4ms
# Speed: 2.4ms preprocess, 26.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.9ms
# Speed: 1.9ms preprocess, 26.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 27.6ms
# Speed: 1.8ms preprocess, 27.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 27.2ms
# Speed: 3.1ms preprocess, 27.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.1ms
# Speed: 3.2ms preprocess, 26.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 27.1ms
# Speed: 3.1ms preprocess, 27.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.8ms
# Speed: 1.7ms preprocess, 26.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 27.1ms
# Speed: 3.2ms preprocess, 27.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.9ms
# Speed: 1.8ms preprocess, 26.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.8ms
# Speed: 2.5ms preprocess, 26.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.4ms
# Speed: 5.5ms preprocess, 26.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.4ms
# Speed: 3.2ms preprocess, 26.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.5ms
# Speed: 2.9ms preprocess, 26.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.4ms
# Speed: 3.3ms preprocess, 26.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 27.2ms
# Speed: 3.2ms preprocess, 27.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.7ms
# Speed: 2.5ms preprocess, 26.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.6ms
# Speed: 1.8ms preprocess, 26.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.8ms
# Speed: 3.1ms preprocess, 26.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.9ms
# Speed: 2.8ms preprocess, 26.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.7ms
# Speed: 1.9ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 27.1ms
# Speed: 1.9ms preprocess, 27.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 27.1ms
# Speed: 1.8ms preprocess, 27.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 27.1ms
# Speed: 2.5ms preprocess, 27.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 27.1ms
# Speed: 1.9ms preprocess, 27.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 27.4ms
# Speed: 3.0ms preprocess, 27.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 25.3ms
# Speed: 1.5ms preprocess, 25.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 25.2ms
# Speed: 2.0ms preprocess, 25.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 25.0ms
# Speed: 2.2ms preprocess, 25.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 26.3ms
# Speed: 2.0ms preprocess, 26.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 26.3ms
# Speed: 3.3ms preprocess, 26.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 26.6ms
# Speed: 2.3ms preprocess, 26.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.4ms
# Speed: 1.9ms preprocess, 26.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.4ms
# Speed: 1.7ms preprocess, 26.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.4ms
# Speed: 2.0ms preprocess, 26.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.6ms
# Speed: 2.1ms preprocess, 26.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.9ms
# Speed: 1.9ms preprocess, 26.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.8ms
# Speed: 3.0ms preprocess, 26.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.7ms
# Speed: 1.9ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.7ms
# Speed: 1.8ms preprocess, 26.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.0ms
# Speed: 3.7ms preprocess, 26.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 25.3ms
# Speed: 2.2ms preprocess, 25.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.3ms
# Speed: 1.5ms preprocess, 26.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 24.6ms
# Speed: 1.8ms preprocess, 24.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 26.7ms
# Speed: 1.6ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 26.9ms
# Speed: 1.7ms preprocess, 26.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.7ms
# Speed: 1.8ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.9ms
# Speed: 2.4ms preprocess, 26.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 25.3ms
# Speed: 3.8ms preprocess, 25.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.6ms
# Speed: 2.9ms preprocess, 26.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.2ms
# Speed: 1.5ms preprocess, 26.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 26.3ms
# Speed: 3.1ms preprocess, 26.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.4ms
# Speed: 3.7ms preprocess, 26.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.6ms
# Speed: 2.2ms preprocess, 26.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 27.3ms
# Speed: 2.0ms preprocess, 27.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.5ms
# Speed: 2.2ms preprocess, 26.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 25.4ms
# Speed: 1.7ms preprocess, 25.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.1ms
# Speed: 2.1ms preprocess, 26.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 25.6ms
# Speed: 2.1ms preprocess, 25.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 25.9ms
# Speed: 2.5ms preprocess, 25.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.4ms
# Speed: 2.1ms preprocess, 26.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.1ms
# Speed: 3.5ms preprocess, 26.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.5ms
# Speed: 1.9ms preprocess, 26.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 25.7ms
# Speed: 2.1ms preprocess, 25.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.0ms
# Speed: 1.9ms preprocess, 26.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.4ms
# Speed: 1.8ms preprocess, 26.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.8ms
# Speed: 2.0ms preprocess, 26.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.7ms
# Speed: 1.9ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.5ms
# Speed: 2.9ms preprocess, 26.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 27.1ms
# Speed: 2.5ms preprocess, 27.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.3ms
# Speed: 2.8ms preprocess, 26.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.3ms
# Speed: 1.5ms preprocess, 26.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.5ms
# Speed: 1.8ms preprocess, 26.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 25.5ms
# Speed: 2.1ms preprocess, 25.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.1ms
# Speed: 2.0ms preprocess, 26.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.0ms
# Speed: 2.0ms preprocess, 26.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 25.9ms
# Speed: 1.9ms preprocess, 25.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.4ms
# Speed: 1.9ms preprocess, 26.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 25.2ms
# Speed: 1.8ms preprocess, 25.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 25.2ms
# Speed: 3.1ms preprocess, 25.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.4ms
# Speed: 1.8ms preprocess, 26.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.4ms
# Speed: 3.2ms preprocess, 26.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.9ms
# Speed: 3.3ms preprocess, 26.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.5ms
# Speed: 2.1ms preprocess, 26.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 26.6ms
# Speed: 2.4ms preprocess, 26.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 26.6ms
# Speed: 2.8ms preprocess, 26.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 26.4ms
# Speed: 3.5ms preprocess, 26.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 26.7ms
# Speed: 1.7ms preprocess, 26.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 24.7ms
# Speed: 1.8ms preprocess, 24.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 27.1ms
# Speed: 1.8ms preprocess, 27.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 27.1ms
# Speed: 2.2ms preprocess, 27.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 27.4ms
# Speed: 2.1ms preprocess, 27.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 26.6ms
# Speed: 3.3ms preprocess, 26.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 26.7ms
# Speed: 2.1ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 26.7ms
# Speed: 1.7ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 26.7ms
# Speed: 2.1ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 26.8ms
# Speed: 1.9ms preprocess, 26.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 26.7ms
# Speed: 2.1ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 truck, 26.7ms
# Speed: 2.8ms preprocess, 26.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 26.8ms
# Speed: 2.1ms preprocess, 26.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 26.3ms
# Speed: 1.7ms preprocess, 26.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 26.3ms
# Speed: 1.8ms preprocess, 26.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 26.3ms
# Speed: 2.1ms preprocess, 26.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 26.2ms
# Speed: 1.7ms preprocess, 26.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 26.2ms
# Speed: 2.3ms preprocess, 26.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 26.6ms
# Speed: 4.0ms preprocess, 26.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 26.7ms
# Speed: 2.9ms preprocess, 26.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 26.8ms
# Speed: 2.5ms preprocess, 26.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 27.1ms
# Speed: 1.9ms preprocess, 27.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 27.2ms
# Speed: 3.0ms preprocess, 27.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 27.1ms
# Speed: 2.2ms preprocess, 27.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 26.6ms
# Speed: 2.4ms preprocess, 26.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 26.5ms
# Speed: 2.0ms preprocess, 26.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 26.6ms
# Speed: 2.1ms preprocess, 26.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 26.6ms
# Speed: 2.0ms preprocess, 26.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 26.1ms
# Speed: 3.1ms preprocess, 26.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 truck, 26.6ms
# Speed: 2.8ms preprocess, 26.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 truck, 26.6ms
# Speed: 1.9ms preprocess, 26.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 truck, 26.4ms
# Speed: 2.7ms preprocess, 26.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 26.2ms
# Speed: 1.8ms preprocess, 26.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 26.4ms
# Speed: 2.8ms preprocess, 26.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 27.1ms
# Speed: 3.2ms preprocess, 27.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 26.8ms
# Speed: 2.2ms preprocess, 26.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 26.7ms
# Speed: 3.0ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 26.6ms
# Speed: 2.0ms preprocess, 26.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 26.4ms
# Speed: 3.5ms preprocess, 26.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 27.4ms
# Speed: 1.6ms preprocess, 27.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 27.6ms
# Speed: 3.0ms preprocess, 27.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 26.2ms
# Speed: 2.1ms preprocess, 26.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 27.6ms
# Speed: 1.6ms preprocess, 27.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 27.4ms
# Speed: 2.1ms preprocess, 27.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 27.6ms
# Speed: 1.9ms preprocess, 27.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 27.5ms
# Speed: 1.6ms preprocess, 27.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 27.4ms
# Speed: 3.2ms preprocess, 27.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 26.9ms
# Speed: 3.4ms preprocess, 26.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 26.0ms
# Speed: 2.6ms preprocess, 26.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 26.2ms
# Speed: 1.6ms preprocess, 26.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 26.4ms
# Speed: 1.9ms preprocess, 26.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 26.8ms
# Speed: 1.7ms preprocess, 26.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 27.0ms
# Speed: 1.7ms preprocess, 27.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 26.7ms
# Speed: 2.6ms preprocess, 26.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 26.2ms
# Speed: 2.0ms preprocess, 26.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 26.7ms
# Speed: 3.2ms preprocess, 26.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 27.4ms
# Speed: 2.9ms preprocess, 27.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 27.1ms
# Speed: 1.5ms preprocess, 27.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 27.2ms
# Speed: 1.8ms preprocess, 27.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 27.6ms
# Speed: 3.3ms preprocess, 27.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 27.7ms
# Speed: 1.9ms preprocess, 27.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 27.1ms
# Speed: 3.4ms preprocess, 27.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 27.6ms
# Speed: 1.7ms preprocess, 27.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 27.0ms
# Speed: 1.8ms preprocess, 27.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 27.0ms
# Speed: 1.8ms preprocess, 27.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 27.0ms
# Speed: 2.7ms preprocess, 27.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 26.3ms
# Speed: 1.6ms preprocess, 26.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 25.7ms
# Speed: 1.7ms preprocess, 25.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 26.5ms
# Speed: 1.7ms preprocess, 26.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 25.3ms
# Speed: 4.2ms preprocess, 25.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 27.2ms
# Speed: 1.6ms preprocess, 27.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 27.2ms
# Speed: 2.4ms preprocess, 27.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 27.1ms
# Speed: 1.9ms preprocess, 27.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 26.2ms
# Speed: 2.1ms preprocess, 26.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 boat, 25.0ms
# Speed: 1.8ms preprocess, 25.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 25.3ms
# Speed: 3.0ms preprocess, 25.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 25.3ms
# Speed: 2.0ms preprocess, 25.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 25.5ms
# Speed: 1.9ms preprocess, 25.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.6ms
# Speed: 2.7ms preprocess, 26.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.4ms
# Speed: 1.9ms preprocess, 26.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.7ms
# Speed: 1.7ms preprocess, 26.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.7ms
# Speed: 2.1ms preprocess, 26.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.9ms
# Speed: 1.6ms preprocess, 26.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 26.7ms
# Speed: 1.7ms preprocess, 26.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.5ms
# Speed: 2.2ms preprocess, 26.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 27.1ms
# Speed: 1.9ms preprocess, 27.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 25.6ms
# Speed: 2.3ms preprocess, 25.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 25.4ms
# Speed: 3.0ms preprocess, 25.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.3ms
# Speed: 1.9ms preprocess, 26.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.5ms
# Speed: 2.0ms preprocess, 26.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 27.0ms
# Speed: 1.5ms preprocess, 27.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.7ms
# Speed: 1.9ms preprocess, 26.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.3ms
# Speed: 1.6ms preprocess, 26.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.3ms
# Speed: 2.8ms preprocess, 26.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.7ms
# Speed: 2.7ms preprocess, 26.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 27.0ms
# Speed: 2.5ms preprocess, 27.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.8ms
# Speed: 3.1ms preprocess, 26.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.9ms
# Speed: 2.1ms preprocess, 26.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.7ms
# Speed: 2.5ms preprocess, 26.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.7ms
# Speed: 3.1ms preprocess, 26.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 26.9ms
# Speed: 1.9ms preprocess, 26.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.7ms
# Speed: 2.5ms preprocess, 26.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 25.8ms
# Speed: 1.9ms preprocess, 25.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.3ms
# Speed: 1.9ms preprocess, 26.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 27.0ms
# Speed: 2.3ms preprocess, 27.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 27.0ms
# Speed: 3.6ms preprocess, 27.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 27.0ms
# Speed: 3.1ms preprocess, 27.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.8ms
# Speed: 2.0ms preprocess, 26.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 26.8ms
# Speed: 2.3ms preprocess, 26.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 26.7ms
# Speed: 2.5ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.6ms
# Speed: 2.0ms preprocess, 26.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.6ms
# Speed: 2.2ms preprocess, 26.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.6ms
# Speed: 2.0ms preprocess, 26.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.8ms
# Speed: 1.6ms preprocess, 26.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.7ms
# Speed: 2.5ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 26.1ms
# Speed: 1.9ms preprocess, 26.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 25.4ms
# Speed: 1.6ms preprocess, 25.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 27.3ms
# Speed: 2.1ms preprocess, 27.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 25.2ms
# Speed: 1.5ms preprocess, 25.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 27.6ms
# Speed: 1.9ms preprocess, 27.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 27.1ms
# Speed: 1.8ms preprocess, 27.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.9ms
# Speed: 3.5ms preprocess, 26.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.7ms
# Speed: 1.7ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 26.8ms
# Speed: 2.0ms preprocess, 26.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.6ms
# Speed: 2.0ms preprocess, 26.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 26.8ms
# Speed: 1.7ms preprocess, 26.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.8ms
# Speed: 2.2ms preprocess, 26.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.8ms
# Speed: 1.8ms preprocess, 26.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 27.3ms
# Speed: 4.9ms preprocess, 27.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 27.1ms
# Speed: 3.2ms preprocess, 27.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 25.5ms
# Speed: 3.2ms preprocess, 25.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 25.6ms
# Speed: 2.8ms preprocess, 25.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.3ms
# Speed: 1.5ms preprocess, 26.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 27.1ms
# Speed: 3.7ms preprocess, 27.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.8ms
# Speed: 1.9ms preprocess, 26.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 27.0ms
# Speed: 2.6ms preprocess, 27.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.8ms
# Speed: 2.2ms preprocess, 26.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 27.3ms
# Speed: 2.8ms preprocess, 27.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 27.3ms
# Speed: 2.3ms preprocess, 27.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 27.2ms
# Speed: 2.0ms preprocess, 27.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 27.4ms
# Speed: 2.7ms preprocess, 27.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 27.3ms
# Speed: 2.4ms preprocess, 27.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 26.9ms
# Speed: 2.9ms preprocess, 26.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
#
# 0: 384x640 10 cars, 1 truck, 26.0ms
# Speed: 4.1ms preprocess, 26.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 27.5ms
# Speed: 1.6ms preprocess, 27.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 27.9ms
# Speed: 3.4ms preprocess, 27.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 27.9ms
# Speed: 4.3ms preprocess, 27.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 27.5ms
# Speed: 2.3ms preprocess, 27.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 27.4ms
# Speed: 2.6ms preprocess, 27.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 27.7ms
# Speed: 5.6ms preprocess, 27.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 27.4ms
# Speed: 2.0ms preprocess, 27.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 27.3ms
# Speed: 3.3ms preprocess, 27.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 27.4ms
# Speed: 2.1ms preprocess, 27.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 27.1ms
# Speed: 2.1ms preprocess, 27.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 27.4ms
# Speed: 3.1ms preprocess, 27.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 27.1ms
# Speed: 2.8ms preprocess, 27.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 27.3ms
# Speed: 1.9ms preprocess, 27.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 27.1ms
# Speed: 1.9ms preprocess, 27.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 27.4ms
# Speed: 1.8ms preprocess, 27.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 27.1ms
# Speed: 1.6ms preprocess, 27.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.6ms
# Speed: 3.9ms preprocess, 27.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.3ms
# Speed: 1.7ms preprocess, 27.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.4ms
# Speed: 3.1ms preprocess, 27.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.3ms
# Speed: 1.6ms preprocess, 27.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.2ms
# Speed: 2.4ms preprocess, 27.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.9ms
# Speed: 2.4ms preprocess, 27.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 26.0ms
# Speed: 2.1ms preprocess, 26.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 28.0ms
# Speed: 3.4ms preprocess, 28.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 trucks, 26.1ms
# Speed: 1.9ms preprocess, 26.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 26.5ms
# Speed: 1.9ms preprocess, 26.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.3ms
# Speed: 4.0ms preprocess, 27.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.4ms
# Speed: 1.5ms preprocess, 27.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.3ms
# Speed: 3.1ms preprocess, 27.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.4ms
# Speed: 2.8ms preprocess, 27.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.3ms
# Speed: 1.9ms preprocess, 27.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.3ms
# Speed: 2.0ms preprocess, 27.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.6ms
# Speed: 2.9ms preprocess, 27.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 28.0ms
# Speed: 2.2ms preprocess, 28.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.7ms
# Speed: 1.9ms preprocess, 27.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.3ms
# Speed: 3.9ms preprocess, 27.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 26.9ms
# Speed: 3.0ms preprocess, 26.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 25.2ms
# Speed: 2.5ms preprocess, 25.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 truck, 26.9ms
# Speed: 1.9ms preprocess, 26.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 26.7ms
# Speed: 2.1ms preprocess, 26.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.8ms
# Speed: 3.9ms preprocess, 27.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 truck, 26.9ms
# Speed: 4.2ms preprocess, 26.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 26.7ms
# Speed: 1.8ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 26.5ms
# Speed: 2.4ms preprocess, 26.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 27.3ms
# Speed: 3.5ms preprocess, 27.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 27.4ms
# Speed: 2.2ms preprocess, 27.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 25.6ms
# Speed: 1.9ms preprocess, 25.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 25.8ms
# Speed: 2.1ms preprocess, 25.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 28.0ms
# Speed: 3.8ms preprocess, 28.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 27.9ms
# Speed: 3.5ms preprocess, 27.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 27.9ms
# Speed: 2.7ms preprocess, 27.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 26.5ms
# Speed: 2.3ms preprocess, 26.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 27.4ms
# Speed: 2.1ms preprocess, 27.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 27.5ms
# Speed: 3.2ms preprocess, 27.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 27.5ms
# Speed: 2.5ms preprocess, 27.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 27.3ms
# Speed: 5.0ms preprocess, 27.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 27.5ms
# Speed: 2.2ms preprocess, 27.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 28.1ms
# Speed: 3.7ms preprocess, 28.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 27.9ms
# Speed: 2.0ms preprocess, 27.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 27.8ms
# Speed: 1.7ms preprocess, 27.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 27.9ms
# Speed: 2.2ms preprocess, 27.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 28.0ms
# Speed: 1.9ms preprocess, 28.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 trucks, 27.8ms
# Speed: 1.9ms preprocess, 27.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 trucks, 27.8ms
# Speed: 1.8ms preprocess, 27.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 trucks, 26.8ms
# Speed: 1.8ms preprocess, 26.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 trucks, 26.8ms
# Speed: 1.6ms preprocess, 26.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 25.9ms
# Speed: 1.8ms preprocess, 25.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 26.9ms
# Speed: 5.2ms preprocess, 26.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 28.1ms
# Speed: 2.2ms preprocess, 28.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.6ms
# Speed: 1.8ms preprocess, 27.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.1ms
# Speed: 3.4ms preprocess, 27.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 truck, 26.8ms
# Speed: 6.5ms preprocess, 26.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 26.2ms
# Speed: 2.0ms preprocess, 26.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.1ms
# Speed: 1.9ms preprocess, 27.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.7ms
# Speed: 2.8ms preprocess, 27.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.3ms
# Speed: 2.0ms preprocess, 27.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.2ms
# Speed: 2.1ms preprocess, 27.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.3ms
# Speed: 2.1ms preprocess, 27.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 27.4ms
# Speed: 2.0ms preprocess, 27.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.4ms
# Speed: 2.3ms preprocess, 27.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 28.0ms
# Speed: 2.3ms preprocess, 28.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.7ms
# Speed: 2.0ms preprocess, 27.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.6ms
# Speed: 4.0ms preprocess, 27.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.8ms
# Speed: 1.7ms preprocess, 27.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.4ms
# Speed: 1.5ms preprocess, 27.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.3ms
# Speed: 1.7ms preprocess, 27.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.2ms
# Speed: 2.3ms preprocess, 27.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 26.4ms
# Speed: 2.0ms preprocess, 26.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 26.9ms
# Speed: 2.1ms preprocess, 26.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 26.6ms
# Speed: 1.7ms preprocess, 26.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.4ms
# Speed: 7.2ms preprocess, 27.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 26.8ms
# Speed: 2.9ms preprocess, 26.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 27.3ms
# Speed: 2.5ms preprocess, 27.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.4ms
# Speed: 2.2ms preprocess, 27.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.3ms
# Speed: 1.8ms preprocess, 27.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.3ms
# Speed: 2.3ms preprocess, 27.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.4ms
# Speed: 2.2ms preprocess, 27.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.3ms
# Speed: 1.9ms preprocess, 27.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.8ms
# Speed: 3.3ms preprocess, 27.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.7ms
# Speed: 2.2ms preprocess, 27.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.9ms
# Speed: 2.7ms preprocess, 27.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.5ms
# Speed: 3.2ms preprocess, 27.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.6ms
# Speed: 2.4ms preprocess, 27.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.4ms
# Speed: 2.0ms preprocess, 27.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.5ms
# Speed: 2.3ms preprocess, 27.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.4ms
# Speed: 1.7ms preprocess, 27.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 27.5ms
# Speed: 2.7ms preprocess, 27.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 27.5ms
# Speed: 1.9ms preprocess, 27.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 27.4ms
# Speed: 1.9ms preprocess, 27.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 27.4ms
# Speed: 3.2ms preprocess, 27.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 28.0ms
# Speed: 3.2ms preprocess, 28.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 27.9ms
# Speed: 2.8ms preprocess, 27.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 28.0ms
# Speed: 3.9ms preprocess, 28.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 27.9ms
# Speed: 2.5ms preprocess, 27.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 28.0ms
# Speed: 3.7ms preprocess, 28.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 27.9ms
# Speed: 3.5ms preprocess, 27.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# Conteo de vehiculos por linea
# Total de vehiculos que pasaron por la linea A: 60
# Total de vehiculos que pasaron por la linea B: 17
# Total de vehiculos que pasaron por la linea C: 9
